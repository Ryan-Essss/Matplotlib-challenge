# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from sklearn import datasets

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_df = pd.merge(mouse_metadata, study_results, how='outer', on='Mouse ID')
# merge_df.head()

# Display the data table for preview
merged_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
total_mice = len(merged_df['Mouse ID'].unique())
total_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicates = merged_df[merged_df[['Mouse ID', 'Timepoint']].duplicated()]
duplicates
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 

g989 = merged_df[merged_df['Mouse ID'] == 'g989']
g989
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

grouped_mice = merged_df.drop_duplicates(subset=['Mouse ID','Timepoint'],keep=False)
grouped_mice = grouped_mice[(grouped_mice['Mouse ID']!='g989')]
grouped_mice
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
total_mice = grouped_mice.loc[:,'Mouse ID'].unique()
len(total_mice)
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
summary_stat = merged_df.groupby('Drug Regimen')

# mean, median, variance, standard deviation, and SEM of the tumor volume. 
tvol_mean = summary_stat['Tumor Volume (mm3)'].mean()
# tvol_mean
tvol_median = summary_stat['Tumor Volume (mm3)'].median()
# tvol_median

tvol_std = summary_stat['Tumor Volume (mm3)'].std()
# tvol_std

tvol_sem = summary_stat['Tumor Volume (mm3)'].sem()
# tvol_sem

tvol_var = summary_stat['Tumor Volume (mm3)'].var()
tvol_var

# Assemble the resulting series into a single summary dataframe.
summary_df = pd.DataFrame({'Mean':tvol_mean, 'Median':tvol_median,
                          'Standard Deviation':tvol_std, 'SEM':tvol_sem, 'Varience':tvol_var})
summary_df
# Out:
#                    Mean     Median  Standard Deviation       SEM   Varience
# Drug Regimen
# Capomulin     40.675741  41.557809            4.994774  0.329346  24.947764
# Ceftamin      52.591172  51.776157            6.268188  0.469821  39.290177
# Infubinol     52.884795  51.820584            6.567243  0.492236  43.128684
# Ketapril      55.235638  53.698743            8.279709  0.603860  68.553577
# Naftisol      54.331565  52.509285            8.134708  0.596466  66.173479
# Placebo       54.033581  52.288934            7.821003  0.581331  61.168083
# Propriva      52.322552  50.854632            6.507770  0.512884  42.351070
# Ramicane      40.216745  40.673236            4.846308  0.320955  23.486704
# Stelasyn      54.233149  52.431737            7.710419  0.573111  59.450562
# Zoniferol     53.236507  51.818479            6.966589  0.516398  48.533355

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
other_summary = summary_stat['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std', 'sem'])
other_summary
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
graph_info = grouped_mice['Drug Regimen'].value_counts()

bar_graph = graph_info.plot(kind='bar', title = "Drug Measurements", 
                            color='yellow')

# set labels
bar_graph.set_xlabel("Drug Regimen")
bar_graph.set_ylabel("Number of Tests")
# bar_graph.set_title("Drug Measurements")


bar_graph.plot

plt.tight_layout()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.

x_axis = grouped_mice['Drug Regimen'].unique()
# x_axis
y_axis = grouped_mice['Drug Regimen'].value_counts()
# y_axis
plt.bar(x_axis,y_axis,color='r',alpha=1,align='center')

# tickers I think
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, x_axis, rotation = "vertical")

# set x and y limits??
plt.xlim(-0.75, len(x_axis)-.25)
plt.ylim(0,max(y_axis)+30)

# labels and a Title
plt.title("Drug Measurements")
plt.xlabel("Drug Types")
plt.ylabel("Number of Tests")
# Out:
# Text(0, 0.5, 'Number of Tests')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# separte the sex of the mice
sex = grouped_mice['Sex'].value_counts()
sex

pie_chart = sex.plot.pie(autopct="%1.2f%%", startangle = 120,
                        title = 'Distribution of Female vs Male mice')

# remove the y axis label
pie_chart.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# labels for sex of mice
labels = ['Males', 'Females']

# values of the sex
sizes = grouped_mice['Sex'].value_counts()

# Colors
colors = ['lightcoral', 'lightskyblue']

# first time trying this explode feature
explode = (0.1, 0)

#creating the actual pie chart & round percentages to 2 decimals
plt.pie(sizes, explode = explode, labels = labels, colors = colors, 
        autopct="%1.2f%%", shadow = True, startangle = 120)
plt.title('Distribution of Female vs Male mice')
# Out:
# Text(0.5, 1.0, 'Distribution of Female vs Male mice')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
treatments = grouped_mice.loc[(grouped_mice["Drug Regimen"] == "Capomulin") | (grouped_mice["Drug Regimen"] == "Ramicane") | (grouped_mice["Drug Regimen"] == "Ceftamin") | (grouped_mice["Drug Regimen"] == "Infubinol"), :]

# Start by getting the last (greatest) timepoint for each mouse
tvol = treatments.groupby('Mouse ID').max()['Tumor Volume (mm3)']
tvol


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
treatment_df = pd.merge(merged_df, tvol, how='outer', on='Mouse ID')
treatment_df

treatment_df = treatment_df.rename(columns={'Tumor Volume (mm3)_x':'Tumor Volume (mm3)',
                                           'Tumor Volume (mm3)_y':'Final Tumor Volume'})
treatment_df

# treatment_df = treatment_df.dropna()
# treatment_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites  Final Tumor Volume
# 0              45.000000                 0                45.0
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
final_tvol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

quartiles = treatment_df['Tumor Volume (mm3)'].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq - lowerq 

# Locate the rows which contain mice on each drug and get the tumor volumes
for treatment in treatments:
    
    final_tvol = treatment_df.loc[treatment_df['Drug Regimen'] == treatment, "Tumor Volume (mm3)"]
    
final_tvol
    
    # add subset 
    
   
    # Determine outliers using upper and lower bounds
print(f"The lower quartile of Tumor Volume is: {lowerq}")
print(f"The upper quartile of Tumor Volume is: {upperq}")
print(f"The interquartile range of Tumor Volume is: {iqr}")
print(f"The median of Tumor Volume is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")


min_vol = treatment_df['Tumor Volume (mm3)'].min()
max_vol = treatment_df['Tumor Volume (mm3)'].max()
print(f"The minimum Tumor Volume is {min_vol}")
print(f"The maximum Tumor Volume is {max_vol}")
# Out:
# The lower quartile of Tumor Volume is: 45.0
# The upper quartile of Tumor Volume is: 56.29220039
# The interquartile range of Tumor Volume is: 11.292200389999998
# The median of Tumor Volume is: 48.95147442
# Values below 28.061699415000003 could be outliers.
# Values above 73.230500975 could be outliers.
# The minimum Tumor Volume is 22.05012627
# The maximum Tumor Volume is 78.56701362

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# set the different drug studies
capomulin = treatment_df[treatment_df['Drug Regimen'] == 'Capomulin']
ramicane = treatment_df[treatment_df['Drug Regimen'] == 'Ramicane']
infubinol = treatment_df[treatment_df['Drug Regimen'] == 'Infubinol']
ceftamin = treatment_df[treatment_df['Drug Regimen'] == 'Ceftamin']

# for the boxplot
capomulin_tumors = capomulin['Final Tumor Volume']
ramicane_tumors = ramicane['Final Tumor Volume']
infubinol_tumors = infubinol['Final Tumor Volume']
ceftamin_tumors = ceftamin['Final Tumor Volume']


# wasn't sure if it needed to be one graph.  This one is ugly, sorry
tumor_data = [capomulin_tumors,ramicane_tumors,infubinol_tumors,ceftamin_tumors]
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
fig1, ax1 = plt.subplots(figsize=(15,15))
ax1.set_title('Final Tumor Volume by Drug', fontsize=20)
ax1.set_ylabel('Tumor Volume Measuremnts',fontsize=10)
ax1.set_xlabel('Drug Regimen',fontsize=10)
ax1.boxplot(tumor_data, labels=treatments, widths=.3)

plt.ylim(40,75)

plt.show()

# fig1, (ax1, ax2, ax3, ax4) = plt.subplots(nrows = 4, figsize=(5,20))

# # Capomulin       
# ax1.set_title("Capomulin Tumor Volume Measurements")
# ax1.set_ylabel("Volume")
# ax1.boxplot(capomulin_tumors)

# # Ramicane
# ax2.set_title("Ramicane Tumor Volume")
# ax2.set_ylabel("Volume")
# ax2.boxplot(ramicane_tumors)

# # Infubinol
# ax3.set_title("Infubinol Tumor Volume")
# ax3.set_ylabel("Volume")
# ax3.boxplot(infubinol_tumors)

# # Ceftamin
# ax4.set_title("Ceftamin Tumor Volume")
# ax4.set_ylabel("Volume")
# ax4.boxplot(ceftamin_tumors)   

# plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# set variables
capomulin = treatment_df[(treatment_df['Drug Regimen']=='Capomulin')&(treatment_df['Mouse ID']=='b128')]
                        
tvol = capomulin['Tumor Volume (mm3)']
timepoint = capomulin['Timepoint']

# plot the graph!
tumor_volume = plt.plot(timepoint,tvol)

plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume')
plt.title('Tumor Volume overtime for Mouse b128')
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin = treatment_df[treatment_df['Drug Regimen'] == 'Capomulin']

capomulin = treatment_df[treatment_df['Drug Regimen'] == 'Capomulin']

# set variables
x_values = capomulin.groupby(capomulin['Mouse ID'])['Weight (g)'].mean()
y_values = capomulin.groupby(capomulin['Mouse ID'])['Tumor Volume (mm3)'].mean()

# plot the graph
plt.scatter(x_values,y_values)
plt.xlabel('Mouse Weight')
plt.ylabel('Tumor Volume')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

capomulin = treatment_df[treatment_df['Drug Regimen'] == 'Capomulin']

# set variables
x_values = capomulin.groupby(capomulin['Mouse ID'])['Weight (g)'].mean()
y_values = capomulin.groupby(capomulin['Mouse ID'])['Tumor Volume (mm3)'].mean()

# add liniear regression to line plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(18,35),fontsize=15,color="red")
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7088568047708717
